# %%
import freq_table
import environment_check
import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Summary
# 1. Variable of interest, 'ProcedureCategoryName', 'ProcedureName', 'ProcedureCode', 'ServiceDate'.
# 2. No missing value found.
# 3. Too many (~7900) categories for 'ProcedureName', 'ProcedureCode'.
# 4. Too many 0s for cross frequency table between 'ProcedureName' and 'ProcedureCode'.
# 5. Using Python, Pandas is $2\times$ faster in loading data.

# %%
environment_check.check_env()
# Out:
# Done!

# %%
file_path = "//data/dept/SOM/ACCORDS/PiFolders/PI_Colborn/UCHealthSOR/Data/C2730_20240628/C2730_Table10_CUMedicineProcedure_20240223.csv"

# %%
# drop columns
drop = ["arb_person_id", "arb_encounter_id"]

# %%
# load file with dask pockage
df = freq_table.load_csv_dask(file_path, drop)
df.shape
# Out:
# (7611644, 4)

# %%
# Check missing value
df.isnull().sum()
# Out:
# ProcedureCategoryName    0
# ProcedureName            0
# ProcedureCode            0
# ServiceDate              0
# dtype: int64

# %%
# transfer datetime
df['ServiceDate'] = pd.to_datetime(df['ServiceDate'], format='%Y-%m-%d')

# %%
# List of columns to convert to string
columns_to_convert = ['ProcedureCategoryName', 'ProcedureName', 'ProcedureCode']

# Convert the specified columns to string
for column in columns_to_convert:
    df[column] = df[column].astype("string")

# %%
df.head(5)
# Out:
#   ProcedureCategoryName                ProcedureName ProcedureCode ServiceDate
# 0                  PQRS  INITIAL PRENATAL CARE VISIT         0500F  2023-03-31
# 1                  PQRS  INITIAL PRENATAL CARE VISIT         0500F  2023-01-23
# 2                  PQRS  INITIAL PRENATAL CARE VISIT         0500F  2022-11-30
# 3                  PQRS  INITIAL PRENATAL CARE VISIT         0500F  2023-07-20
# 4                  PQRS  INITIAL PRENATAL CARE VISIT         0500F  2023-02-03

# %%
df.isnull().sum()
# Out:
# ProcedureCategoryName    0
# ProcedureName            0
# ProcedureCode            0
# ServiceDate              0
# dtype: int64

# %%
df.dtypes
# Out:
# ProcedureCategoryName    string[python]
# ProcedureName            string[python]
# ProcedureCode            string[python]
# ServiceDate              datetime64[ns]
# dtype: object

# %%
# one-way table
# normalize='columns'
dfs = []
for column in columns_to_convert:
    dfs.append(pd.crosstab(index=df[column], columns="Count"))

# %%
# style.pipe(make_pretty)
dfs[0].rename_axis(columns=None).style.pipe(freq_table.pretty_freq_df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c257">
#   <caption>Frequency Table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c257_level0_col0" class="col_heading level0 col0" >Count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ProcedureCategoryName</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c257_level0_row0" class="row_heading level0 row0" >ANESTHESIA</th>
#       <td id="T_6c257_row0_col0" class="data row0 col0" >468651</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row1" class="row_heading level0 row1" >COSMETIC</th>
#       <td id="T_6c257_row1_col0" class="data row1 col0" >391</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row2" class="row_heading level0 row2" >CU MEDICINE ADMIN</th>
#       <td id="T_6c257_row2_col0" class="data row2 col0" >2722</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row3" class="row_heading level0 row3" >DRUGS PHARMACY</th>
#       <td id="T_6c257_row3_col0" class="data row3 col0" >3898</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row4" class="row_heading level0 row4" >EM CONSULTS IP</th>
#       <td id="T_6c257_row4_col0" class="data row4 col0" >19780</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row5" class="row_heading level0 row5" >EM CONSULTS OP</th>
#       <td id="T_6c257_row5_col0" class="data row5 col0" >29484</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row6" class="row_heading level0 row6" >EM CRITICAL CARE SVCS</th>
#       <td id="T_6c257_row6_col0" class="data row6 col0" >207231</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row7" class="row_heading level0 row7" >EM OBSERV CARE SUBSEQ</th>
#       <td id="T_6c257_row7_col0" class="data row7 col0" >10881</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row8" class="row_heading level0 row8" >EM OFF OP VSTS EST</th>
#       <td id="T_6c257_row8_col0" class="data row8 col0" >861220</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row9" class="row_heading level0 row9" >EM OFF OP VSTS NEW</th>
#       <td id="T_6c257_row9_col0" class="data row9 col0" >264714</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row10" class="row_heading level0 row10" >EM OTHER SVCS</th>
#       <td id="T_6c257_row10_col0" class="data row10 col0" >7393</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row11" class="row_heading level0 row11" >EM VSTS IP INITIAL</th>
#       <td id="T_6c257_row11_col0" class="data row11 col0" >171346</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row12" class="row_heading level0 row12" >EM VSTS IP SUBSEQ</th>
#       <td id="T_6c257_row12_col0" class="data row12 col0" >832814</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row13" class="row_heading level0 row13" >EVAL AND MGMT</th>
#       <td id="T_6c257_row13_col0" class="data row13 col0" >341269</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row14" class="row_heading level0 row14" >LABORATORY</th>
#       <td id="T_6c257_row14_col0" class="data row14 col0" >321493</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row15" class="row_heading level0 row15" >MEDICAL</th>
#       <td id="T_6c257_row15_col0" class="data row15 col0" >49</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row16" class="row_heading level0 row16" >MEDICINE</th>
#       <td id="T_6c257_row16_col0" class="data row16 col0" >910129</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row17" class="row_heading level0 row17" >OTHER MED SVCS</th>
#       <td id="T_6c257_row17_col0" class="data row17 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row18" class="row_heading level0 row18" >PQRS</th>
#       <td id="T_6c257_row18_col0" class="data row18 col0" >27920</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row19" class="row_heading level0 row19" >PRE AND POST OP VISITS</th>
#       <td id="T_6c257_row19_col0" class="data row19 col0" >486553</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row20" class="row_heading level0 row20" >PSYCHIATRY PSYCHOLOGY</th>
#       <td id="T_6c257_row20_col0" class="data row20 col0" >7245</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row21" class="row_heading level0 row21" >RADIOLOGY</th>
#       <td id="T_6c257_row21_col0" class="data row21 col0" >1530708</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row22" class="row_heading level0 row22" >RESEARCH</th>
#       <td id="T_6c257_row22_col0" class="data row22 col0" >84</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row23" class="row_heading level0 row23" >SUPPLIES</th>
#       <td id="T_6c257_row23_col0" class="data row23 col0" >9538</td>
#     </tr>
#     <tr>
#       <th id="T_6c257_level0_row24" class="row_heading level0 row24" >SURGERY</th>
#       <td id="T_6c257_row24_col0" class="data row24 col0" >1096128</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfs[1].rename_axis(columns=None).style.pipe(freq_table.pretty_freq_df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f2776">
#   <caption>Frequency Table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2776_level0_col0" class="col_heading level0 col0" >Count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ProcedureName</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2776_level0_row0" class="row_heading level0 row0" >12lead electrocardiogram ecg performed</th>
#       <td id="T_f2776_row0_col0" class="data row0 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row1" class="row_heading level0 row1" >1MM SHOULDER SLING SWATHE LG</th>
#       <td id="T_f2776_row1_col0" class="data row1 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row2" class="row_heading level0 row2" >1ST HOSP IP/OBS HIGH 75</th>
#       <td id="T_f2776_row2_col0" class="data row2 col0" >84070</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row3" class="row_heading level0 row3" >1ST HOSP IP/OBS MODERATE 55</th>
#       <td id="T_f2776_row3_col0" class="data row3 col0" >53822</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row4" class="row_heading level0 row4" >1ST HOSP IP/OBS SF/LOW 40</th>
#       <td id="T_f2776_row4_col0" class="data row4 col0" >33454</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row5" class="row_heading level0 row5" >1ST NF CARE HIGH MDM 45</th>
#       <td id="T_f2776_row5_col0" class="data row5 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row6" class="row_heading level0 row6" >1ST NF CARE MODERATE MDM 35</th>
#       <td id="T_f2776_row6_col0" class="data row6 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row7" class="row_heading level0 row7" >3/4 DRESS OTC INSERT</th>
#       <td id="T_f2776_row7_col0" class="data row7 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row8" class="row_heading level0 row8" >3/4 LENGTH HEEL LIFTS</th>
#       <td id="T_f2776_row8_col0" class="data row8 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row9" class="row_heading level0 row9" >3D RENDERING W I AND R CT MRI US REQ IMAGE POSTPROC ON INDEPEND WKSTATION</th>
#       <td id="T_f2776_row9_col0" class="data row9 col0" >2893</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row10" class="row_heading level0 row10" >3D RENDERING W I&R CT MRI US NOT REQ IMAGE POSTPROC ON INDEPEND WKSTATION</th>
#       <td id="T_f2776_row10_col0" class="data row10 col0" >6274</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row11" class="row_heading level0 row11" >5 IN FIXED WHEELS FOR WALKER</th>
#       <td id="T_f2776_row11_col0" class="data row11 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row12" class="row_heading level0 row12" >A2M PRP INJ, ALL INCLUSIVE PKG; BILATERAL</th>
#       <td id="T_f2776_row12_col0" class="data row12 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row13" class="row_heading level0 row13" >AAA SCREENING</th>
#       <td id="T_f2776_row13_col0" class="data row13 col0" >73</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row14" class="row_heading level0 row14" >ABDOM LYMPHADENECTOMY REGION INCL CELIAC ETC W-W/O PARA-AORTIC & VENA CAVA ETC</th>
#       <td id="T_f2776_row14_col0" class="data row14 col0" >45</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row15" class="row_heading level0 row15" >ABDOMINAL PARACENTESIS WITH IMAGING GUIDANCE</th>
#       <td id="T_f2776_row15_col0" class="data row15 col0" >5475</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row16" class="row_heading level0 row16" >ABDOMINAL PARACENTESIS WITHOUT IMAGING GUIDANCE</th>
#       <td id="T_f2776_row16_col0" class="data row16 col0" >416</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row17" class="row_heading level0 row17" >ABLATION</th>
#       <td id="T_f2776_row17_col0" class="data row17 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row18" class="row_heading level0 row18" >ABLATION 1 OR MORE LIVER TUMOR PERCUT CRYOABLATION</th>
#       <td id="T_f2776_row18_col0" class="data row18 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row19" class="row_heading level0 row19" >ABLATION 1 OR MORE LIVER TUMOR(S) PERCUTANEOUS RADIOFREQUENCY</th>
#       <td id="T_f2776_row19_col0" class="data row19 col0" >141</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row20" class="row_heading level0 row20" >ABLATION 1/MORE RENAL TUMOR/S PERCUTANEOUS UNILATERAL RADIOFREQUENCY</th>
#       <td id="T_f2776_row20_col0" class="data row20 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row21" class="row_heading level0 row21" >ABLATION OPEN ONE OR MORE LIVER TUMORS RADIOFREQUENCY</th>
#       <td id="T_f2776_row21_col0" class="data row21 col0" >59</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row22" class="row_heading level0 row22" >ABLATION RENAL TUMOR/S UNILATERAL PERCUTANEOUS CRYOTHERAPY</th>
#       <td id="T_f2776_row22_col0" class="data row22 col0" >40</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row23" class="row_heading level0 row23" >ABLATION ST INFERIOR TUBINATES UNI/BILATERAL ANY METHOD INTRAMURAL</th>
#       <td id="T_f2776_row23_col0" class="data row23 col0" >7</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row24" class="row_heading level0 row24" >ABLATION ST INFERIOR TURBINATES UNI/BILAT ANY METHOD SUPERFICIAL</th>
#       <td id="T_f2776_row24_col0" class="data row24 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row25" class="row_heading level0 row25" >ABLATION THER 1+ PULM TUMORS PERQ CRYOABLATION</th>
#       <td id="T_f2776_row25_col0" class="data row25 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row26" class="row_heading level0 row26" >ABLATION THERAPY REDUCT ERADICT 1 OR MORE BONE TUMORS INCL ADJ ST CRYOABLATION</th>
#       <td id="T_f2776_row26_col0" class="data row26 col0" >247</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row27" class="row_heading level0 row27" >ABLATION THERAPY REDUCT OR ERADIC 1 OR MORE BONE TUMORS INCL IG WP RADIOFREQ</th>
#       <td id="T_f2776_row27_col0" class="data row27 col0" >248</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row28" class="row_heading level0 row28" >ABLTJ PERC CRYOABLTJ IMG GDN NRV PLEX/TRNCL NRV</th>
#       <td id="T_f2776_row28_col0" class="data row28 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row29" class="row_heading level0 row29" >ABSCESS LOCALIZATION LIMITED AREA</th>
#       <td id="T_f2776_row29_col0" class="data row29 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row30" class="row_heading level0 row30" >ABSCESS LOCALIZATION TOMOGRAPHIC (SPECT)</th>
#       <td id="T_f2776_row30_col0" class="data row30 col0" >23</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row31" class="row_heading level0 row31" >ABSCESS LOCALIZATION WHOLE BODY</th>
#       <td id="T_f2776_row31_col0" class="data row31 col0" >40</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row32" class="row_heading level0 row32" >ACETABULOPLASTY</th>
#       <td id="T_f2776_row32_col0" class="data row32 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row33" class="row_heading level0 row33" >ACETABULOPLASTY RESECTION FEMORAL HEAD</th>
#       <td id="T_f2776_row33_col0" class="data row33 col0" >47</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row34" class="row_heading level0 row34" >ACHILLES WEDGE</th>
#       <td id="T_f2776_row34_col0" class="data row34 col0" >34</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row35" class="row_heading level0 row35" >ACNE SURGERY</th>
#       <td id="T_f2776_row35_col0" class="data row35 col0" >33</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row36" class="row_heading level0 row36" >ACROMIOPLASTY/ACROMINECTOMY PARTIAL W-W/O CORACOACROMIAL LIGAMENT RELEASE</th>
#       <td id="T_f2776_row36_col0" class="data row36 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f2776_level0_row37" class="row_heading level0 row37" >ACTIGRAPHY TEST/RECORD-IN

# %%
dfs[2].rename_axis(columns=None).style.pipe(freq_table.pretty_freq_df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_05c47">
#   <caption>Frequency Table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05c47_level0_col0" class="col_heading level0 col0" >Count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ProcedureCode</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05c47_level0_row0" class="row_heading level0 row0" >00033</th>
#       <td id="T_05c47_row0_col0" class="data row0 col0" >6</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row1" class="row_heading level0 row1" >00034</th>
#       <td id="T_05c47_row1_col0" class="data row1 col0" >9</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row2" class="row_heading level0 row2" >00035</th>
#       <td id="T_05c47_row2_col0" class="data row2 col0" >43</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row3" class="row_heading level0 row3" >00036</th>
#       <td id="T_05c47_row3_col0" class="data row3 col0" >19</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row4" class="row_heading level0 row4" >00091</th>
#       <td id="T_05c47_row4_col0" class="data row4 col0" >71</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row5" class="row_heading level0 row5" >00093</th>
#       <td id="T_05c47_row5_col0" class="data row5 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row6" class="row_heading level0 row6" >00096</th>
#       <td id="T_05c47_row6_col0" class="data row6 col0" >208</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row7" class="row_heading level0 row7" >00098</th>
#       <td id="T_05c47_row7_col0" class="data row7 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row8" class="row_heading level0 row8" >00100</th>
#       <td id="T_05c47_row8_col0" class="data row8 col0" >393</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row9" class="row_heading level0 row9" >00102</th>
#       <td id="T_05c47_row9_col0" class="data row9 col0" >15</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row10" class="row_heading level0 row10" >00103</th>
#       <td id="T_05c47_row10_col0" class="data row10 col0" >3046</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row11" class="row_heading level0 row11" >00104</th>
#       <td id="T_05c47_row11_col0" class="data row11 col0" >13</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row12" class="row_heading level0 row12" >00120</th>
#       <td id="T_05c47_row12_col0" class="data row12 col0" >2124</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row13" class="row_heading level0 row13" >00124</th>
#       <td id="T_05c47_row13_col0" class="data row13 col0" >82</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row14" class="row_heading level0 row14" >00126</th>
#       <td id="T_05c47_row14_col0" class="data row14 col0" >61</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row15" class="row_heading level0 row15" >00140</th>
#       <td id="T_05c47_row15_col0" class="data row15 col0" >7582</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row16" class="row_heading level0 row16" >00142</th>
#       <td id="T_05c47_row16_col0" class="data row16 col0" >22170</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row17" class="row_heading level0 row17" >00144</th>
#       <td id="T_05c47_row17_col0" class="data row17 col0" >944</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row18" class="row_heading level0 row18" >00145</th>
#       <td id="T_05c47_row18_col0" class="data row18 col0" >6075</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row19" class="row_heading level0 row19" >00147</th>
#       <td id="T_05c47_row19_col0" class="data row19 col0" >32</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row20" class="row_heading level0 row20" >00148</th>
#       <td id="T_05c47_row20_col0" class="data row20 col0" >23</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row21" class="row_heading level0 row21" >001588</th>
#       <td id="T_05c47_row21_col0" class="data row21 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row22" class="row_heading level0 row22" >001595</th>
#       <td id="T_05c47_row22_col0" class="data row22 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row23" class="row_heading level0 row23" >001597</th>
#       <td id="T_05c47_row23_col0" class="data row23 col0" >10</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row24" class="row_heading level0 row24" >001598</th>
#       <td id="T_05c47_row24_col0" class="data row24 col0" >31</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row25" class="row_heading level0 row25" >00160</th>
#       <td id="T_05c47_row25_col0" class="data row25 col0" >6464</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row26" class="row_heading level0 row26" >00162</th>
#       <td id="T_05c47_row26_col0" class="data row26 col0" >32</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row27" class="row_heading level0 row27" >00164</th>
#       <td id="T_05c47_row27_col0" class="data row27 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row28" class="row_heading level0 row28" >00170</th>
#       <td id="T_05c47_row28_col0" class="data row28 col0" >2874</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row29" class="row_heading level0 row29" >00172</th>
#       <td id="T_05c47_row29_col0" class="data row29 col0" >18</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row30" class="row_heading level0 row30" >00174</th>
#       <td id="T_05c47_row30_col0" class="data row30 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row31" class="row_heading level0 row31" >00176</th>
#       <td id="T_05c47_row31_col0" class="data row31 col0" >91</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row32" class="row_heading level0 row32" >001766</th>
#       <td id="T_05c47_row32_col0" class="data row32 col0" >38</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row33" class="row_heading level0 row33" >00190</th>
#       <td id="T_05c47_row33_col0" class="data row33 col0" >1208</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row34" class="row_heading level0 row34" >00192</th>
#       <td id="T_05c47_row34_col0" class="data row34 col0" >314</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row35" class="row_heading level0 row35" >00210</th>
#       <td id="T_05c47_row35_col0" class="data row35 col0" >6525</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row36" class="row_heading level0 row36" >00211</th>
#       <td id="T_05c47_row36_col0" class="data row36 col0" >793</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row37" class="row_heading level0 row37" >00212</th>
#       <td id="T_05c47_row37_col0" class="data row37 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row38" class="row_heading level0 row38" >00214</th>
#       <td id="T_05c47_row38_col0" class="data row38 col0" >311</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row39" class="row_heading level0 row39" >00215</th>
#       <td id="T_05c47_row39_col0" class="data row39 col0" >273</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row40" class="row_heading level0 row40" >00216</th>
#       <td id="T_05c47_row40_col0" class="data row40 col0" >625</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row41" class="row_heading level0 row41" >00218</th>
#       <td id="T_05c47_row41_col0" class="data row41 col0" >526</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row42" class="row_heading level0 row42" >00220</th>
#       <td id="T_05c47_row42_col0" class="data row42 col0" >848</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row43" class="row_heading level0 row43" >00222</th>
#       <td id="T_05c47_row43_col0" class="data row43 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row44" class="row_heading level0 row44" >00300</th>
#       <td id="T_05c47_row44_col0" class="data row44 col0" >7608</td>
#     </tr>
#     <tr>
#       <th id="T_05c47_level0_row45" class="row_heading level0 row45" >00320</th>
#       <td id="T_05c47_row45_

# %%
# two way 
pd.crosstab(index=df["ProcedureName"], columns=df["ProcedureCode"], margins=True)
# Out:
# ProcedureCode                                       00033  00034  00035  \
# ProcedureName
# 12lead electrocardiogram ecg performed                  0      0      0
# 1MM SHOULDER SLING SWATHE LG                            0      0      0
# 1ST HOSP IP/OBS HIGH 75                                 0      0      0
# 1ST HOSP IP/OBS MODERATE 55                             0      0      0
# 1ST HOSP IP/OBS SF/LOW 40                               0      0      0
# ...                                                   ...    ...    ...
# XCAPSL CTRC RMVL INSJ IO LENS PRSTH CPLX INSJ 1+        0      0      0
# XEOMIN COSMETIC PER UNIT                                0      0      0
# ZOSTER SHINGLES VACCINE HZV RECOMBINANT SUB UNI...      0      0      0
# ZOSTER VACC, SC                                         0      0      0
# All                                                     6      9     43
#
# ProcedureCode                                       00036  00091  00093  \
# ProcedureName
# 12lead electrocardiogram ecg performed                  0      0      0
# 1MM SHOULDER SLING SWATHE LG                            0      0      0
# 1ST HOSP IP/OBS HIGH 75                                 0      0      0
# 1ST HOSP IP/OBS MODERATE 55                             0      0      0
# 1ST HOSP IP/OBS SF/LOW 40                               0      0      0
# ...                                                   ...    ...    ...
# XCAPSL CTRC RMVL INSJ IO LENS PRSTH CPLX INSJ 1+        0      0      0
# XEOMIN COSMETIC PER UNIT                                0      0      0
# ZOSTER SHINGLES VACCINE HZV RECOMBINANT SUB UNI...      0      0      0
# ZOSTER VACC, SC                                         0      0      0
# All                                                    19     71      1
#
# ProcedureCode                                       00096  00098  00100  \
# ProcedureName
# 12lead electrocardiogram ecg performed                  0      0      0
# 1MM SHOULDER SLING SWATHE LG                            0      0      0
# 1ST HOSP IP/OBS HIGH 75                                 0      0      0
# 1ST HOSP IP/OBS MODERATE 55                             0      0      0
# 1ST HOSP IP/OBS SF/LOW 40                               0      0      0
# ...                                                   ...    ...    ...
# XCAPSL CTRC RMVL INSJ IO LENS PRSTH CPLX INSJ 1+        0      0      0
# XEOMIN COSMETIC PER UNIT                                0      0      0
# ZOSTER SHINGLES VACCINE HZV RECOMBINANT SUB UNI...      0      0      0
# ZOSTER VACC, SC                                         0      0      0
# All                                                   208      1    393
#
# ProcedureCode                                       00102  ...  S4028  S4035  \
# ProcedureName                                              ...
# 12lead electrocardiogram ecg performed                  0  ...      0      0
# 1MM SHOULDER SLING SWATHE LG                            0  ...      0      0
# 1ST HOSP IP/OBS HIGH 75                                 0  ...      0      0
# 1ST HOSP IP/OBS MODERATE 55                             0  ...      0      0
# 1ST HOSP IP/OBS SF/LOW 40                               0  ...      0      0
# ...                                                   ...  ...    ...    ...
# XCAPSL CTRC RMVL INSJ IO LENS PRSTH CPLX INSJ 1+        0  ...      0      0
# XEOMIN COSMETIC PER UNIT                                0  ...      0      0
# ZOSTER SHINGLES VACCINE HZV RECOMBINANT SUB UNI...      0  ...      0      0
# ZOSTER VACC, SC                                         0  ...      0      0
# All                                                    15  ...     37      1
#
# ProcedureCode                                       S4037  S8032  S8451  \
# ProcedureName
# 12lead electrocardiogram ecg performed                  0      0      0
# 1MM SHOULDER SLING SWATHE LG                            0      0      0
# 1ST HOSP IP/OBS HIGH 75                                 0      0      0
# 1ST HOSP IP/OBS MODERATE 55                             0      0      0
# 1ST HOSP IP/OBS SF/LOW 40                               0      0      0
# ...                                                   ...    ...    ...
# XCAPSL CTRC RMVL INSJ IO LENS PRSTH CPLX INSJ 1+        0      0      0
# XEOMIN COSMETIC PER UNIT                                0      0      0
# ZOSTER SHINGLES VACCINE HZV RECOMBINANT SUB UNI...      0      0      0
# ZOSTER VACC, SC                                         0      0      0
# All                                                   141     13      1
#
# ProcedureCode                                       S9982  S9986  T5999  \
# ProcedureName
# 12lead electrocardiogram ecg performed                  0      0      0
# 1MM SHOULDER SLING SWATHE LG                            0      0      0
# 1ST HOSP IP/OBS HIGH 75                                 0      0      0
# 1ST HOSP IP/OBS MODERATE 55                             0      0      0
# 1ST HOSP IP/OBS SF/LOW 40                               0      0      0
# ...                                                   ...    ...    ...
# XCAPSL CTRC RMVL INSJ IO LENS PRSTH CPLX INSJ 1+        0      0      0
# XEOMIN COSMETIC PER UNIT                                0      0      0
# ZOSTER SHINGLES VACCINE HZV RECOMBINANT SUB UNI...      0      0      0
# ZOSTER VACC, SC                                         0      0      0
# All                                                     1     10      9
#
# ProcedureCode                                       Z0760      All
# ProcedureName
# 12lead electrocardiogram ecg performed                  0        4
# 1MM SHOULDER SLING SWATHE LG                            0        3
# 1ST HOSP IP/OBS HIGH 75                                 0    84070
# 1ST HOSP IP/OBS MODERATE 55                             0    53822
# 1ST HOSP IP/OBS SF/LOW 40                               0    33454
# ...                                                   ...      ...
# XCAPSL CTRC RMVL INSJ IO LENS PRSTH CPLX INSJ 1+        0        2
# XEOMIN COSMETIC PER UNIT                                0        1
# ZOSTER SHINGLES VACCINE HZV RECOMBINANT SUB UNI...      0      124
# ZOSTER VACC, SC                                         0        4
# All                                                     6  7611644
#
# [7875 rows x 7875 columns]
